# %% [markdown]
# # Docentes Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_columns', None)

# %%
sns.set_palette("Dark2")

# %%
uri = 'https://github.com/mauricioarauujo/capes-data-analysis/blob/develop/data/Docentes_2013-2019.parquet?raw=true'

# %%
docentes_df = pd.read_parquet(uri)

# %%
docentes_df.head()
# Out:
#    AN_BASE  CD_AREA_AVALIACAO NM_GRANDE_AREA_CONHECIMENTO  \
# 0     2019                 49            MULTIDISCIPLINAR
# 1     2019                 38            CIÊNCIAS HUMANAS
# 2     2019                 27  CIÊNCIAS SOCIAIS APLICADAS
# 3     2019                 45            MULTIDISCIPLINAR
# 4     2019                  7         CIÊNCIAS BIOLÓGICAS
#
#   NM_AREA_CONHECIMENTO CD_PROGRAMA_IES       NM_GRAU_PROGRAMA  \
# 0  CIÊNCIAS AMBIENTAIS   10001018017P9               MESTRADO
# 1             EDUCAÇÃO   10001018016P2  MESTRADO PROFISSIONAL
# 2        ADMINISTRAÇÃO   53045009001P3  MESTRADO PROFISSIONAL
# 3     INTERDISCIPLINAR   10001018004P4     MESTRADO/DOUTORADO
# 4             ECOLOGIA   10001018041P7               MESTRADO
#
#   NM_MODALIDADE_PROGRAMA CD_CONCEITO_PROGRAMA SG_ENTIDADE_ENSINO  \
# 0              ACADÊMICO                    3               UNIR
# 1           PROFISSIONAL                    4               UNIR
# 2           PROFISSIONAL                    3               UNIR
# 3              ACADÊMICO                    4               UNIR
# 4              ACADÊMICO                    A               UNIR
#
#                  NM_ENTIDADE_ENSINO DS_DEPENDENCIA_ADMINISTRATIVA  \
# 0  UNIVERSIDADE FEDERAL DE RONDÔNIA                       PÚBLICA
# 1  UNIVERSIDADE FEDERAL DE RONDÔNIA                       PÚBLICA
# 2  UNIVERSIDADE FEDERAL DE RONDÔNIA                       PÚBLICA
# 3  UNIVERSIDADE FEDERAL DE RONDÔNIA                       PÚBLICA
# 4  UNIVERSIDADE FEDERAL DE RONDÔNIA                       PÚBLICA
#
#   CS_STATUS_JURIDICO NM_MUNICIPIO_PROGRAMA_IES SG_UF_PROGRAMA NM_REGIAO  \
# 0            FEDERAL            ROLIM DE MOURA             RO     NORTE
# 1            FEDERAL               PORTO VELHO             RO     NORTE
# 2            FEDERAL               PORTO VELHO             RO     NORTE
# 3            FEDERAL               PORTO VELHO             RO     NORTE
# 4            FEDERAL               PORTO VELHO             RO     NORTE
#
#   TP_SEXO_DOCENTE  AN_NASCIMENTO_DOCENTE DS_TIPO_NACIONALIDADE_DOCENTE  \
# 0        FEMININO                   1968                    BRASILEIRO
# 1       MASCULINO                   1963                    BRASILEIRO
# 2        FEMININO                   1972                    BRASILEIRO
# 3       MASCULINO                   1978                    BRASILEIRO
# 4       MASCULINO                   1976                    BRASILEIRO
#
#   NM_PAIS_NACIONALIDADE_DOCENTE DS_CATEGORIA_DOCENTE  \
# 0                        BRASIL           PERMANENTE
# 1                        BRASIL           PERMANENTE
# 2                        BRASIL          COLABORADOR
# 3                        BRASIL           PERMANENTE
# 4                        BRASIL           PERMANENTE
#
#   DS_TIPO_VINCULO_DOCENTE_IES   DS_REGIME_TRABALHO IN_DOUTOR  AN_TITULACAO  \
# 0            SERVIDOR PÚBLICO  DEDICAÇÃO EXCLUSIVA         S        2004.0
# 1            SERVIDOR PÚBLICO  DEDICAÇÃO EXCLUSIVA         S        2012.0
# 2            SERVIDOR PÚBLICO  DEDICAÇÃO EXCLUSIVA         S        2013.0
# 3                         CLT              PARCIAL         S        2007.0
# 4            SERVIDOR PÚBLICO              PARCIAL         S        2004.0
#
#   NM_GRAU_TITULACAO                    NM_AREA_BASICA_TITULACAO  \
# 0         DOUTORADO  RECURSOS FLORESTAIS E ENGENHARIA FLORESTAL
# 1         DOUTORADO                                    EDUCAÇÃO
# 2         DOUTORADO                               ADMINISTRAÇÃO
# 3         DOUTORADO                        MELHORAMENTO VEGETAL
# 4         DOUTORADO                              BIOLOGIA GERAL
#
#   SG_IES_TITULACAO NM_PAIS_IES_TITULACAO
# 0             UFSM                BRASIL
# 1             UERJ                BRASIL
# 2            UFRGS                BRASIL
# 3              UFV                BRASIL
# 4              UNB                BRASIL

# %%
docentes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662665 entries, 0 to 662664
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   AN_BASE                        662665 non-null  int64
#  1   CD_AREA_AVALIACAO              662665 non-null  int64
#  2   NM_GRANDE_AREA_CONHECIMENTO    662665 non-null  object
#  3   NM_AREA_CONHECIMENTO           662665 non-null  object
#  4   CD_PROGRAMA_IES                662665 non-null  object
#  5   NM_GRAU_PROGRAMA               662665 non-null  object
#  6   NM_MODALIDADE_PROGRAMA         662665 non-null  object
#  7   CD_CONCEITO_PROGRAMA           662665 non-null  object
#  8   SG_ENTIDADE_ENSINO             662665 non-null  object
#  9   NM_ENTIDADE_ENSINO             662665 non-null  object
#  10  DS_DEPENDENCIA_ADMINISTRATIVA  662665 non-null  object
#  11  CS_STATUS_JURIDICO             662665 non-null  object
#  12  NM_MUNICIPIO_PROGRAMA_IES      662665 non-null  object
#  13  SG_UF_PROGRAMA                 662665 non-null  object
#  14  NM_REGIAO                      662665 non-null  object
#  15  TP_SEXO_DOCENTE                662665 non-null  object
#  16  AN_NASCIMENTO_DOCENTE          662665 non-null  int64
#  17  DS_TIPO_NACIONALIDADE_DOCENTE  662665 non-null  object
#  18  NM_PAIS_NACIONALIDADE_DOCENTE  662665 non-null  object
#  19  DS_CATEGORIA_DOCENTE           662665 non-null  object
#  20  DS_TIPO_VINCULO_DOCENTE_IES    662660 non-null  object
#  21  DS_REGIME_TRABALHO             662665 non-null  object
#  22  IN_DOUTOR                      662665 non-null  object
#  23  AN_TITULACAO                   662651 non-null  float64
#  24  NM_GRAU_TITULACAO              662651 non-null  object
#  25  NM_AREA_BASICA_TITULACAO       662651 non-null  object
#  26  SG_IES_TITULACAO               648813 non-null  object
#  27  NM_PAIS_IES_TITULACAO          662651 non-null  object
# dtypes: float64(1), int64(3), object(24)
# memory usage: 141.6+ MB

# %%
docentes_df.CD_PROGRAMA_IES.value_counts()
# Out:
# 31075010001P2    7924
# 33283010001P5    3869
# 23001011069P5    3823
# 22003010017P5    1669
# 31001017155P1    1616
#                  ...
# 25001019173P2       8
# 52001016017P7       8
# 20001010048P0       8
# 52001016035P5       4
# 31005012022P7       1
# Name: CD_PROGRAMA_IES, Length: 4723, dtype: int64

# %%
docentes_df[['CD_PROGRAMA_IES','CD_CONCEITO_PROGRAMA']]
# Out:
#        CD_PROGRAMA_IES CD_CONCEITO_PROGRAMA
# 0        10001018017P9                    3
# 1        10001018016P2                    4
# 2        53045009001P3                    3
# 3        10001018004P4                    4
# 4        10001018041P7                    A
# ...                ...                  ...
# 662660   53044002001P7                    3
# 662661   53044002001P7                    3
# 662662   53044002001P7                    3
# 662663   53044002001P7                    3
# 662664   12001015038P1                    4
#
# [662665 rows x 2 columns]

# %%
sns.countplot(data = docentes_df, x = 'AN_BASE')
# Out:
# <AxesSubplot:xlabel='AN_BASE', ylabel='count'>
