# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('br-capes-colsucup-prog-2013a2016-2020-06-12_2016.csv',sep=';',encoding='latin1')

# %%
df.head()
# Out:
#    AN_BASE NM_GRANDE_AREA_CONHECIMENTO NM_AREA_CONHECIMENTO  \
# 0     2016         CIÊNCIAS BIOLÓGICAS        PARASITOLOGIA
# 1     2016            MULTIDISCIPLINAR     INTERDISCIPLINAR
# 2     2016            CIÊNCIAS HUMANAS            GEOGRAFIA
# 3     2016  CIÊNCIAS SOCIAIS APLICADAS        ADMINISTRAÇÃO
# 4     2016            CIÊNCIAS HUMANAS           PSICOLOGIA
#
#     NM_SUBAREA_CONHECIMENTO NM_ESPECIALIDADE  CD_AREA_AVALIACAO  \
# 0             NÃO SE APLICA    NÃO SE APLICA                  9
# 1  MEIO AMBIENTE E AGRÁRIAS    NÃO SE APLICA                 45
# 2             NÃO SE APLICA    NÃO SE APLICA                 36
# 3             NÃO SE APLICA    NÃO SE APLICA                 27
# 4             NÃO SE APLICA    NÃO SE APLICA                 37
#
#                                    NM_AREA_AVALIACAO  CD_ENTIDADE_CAPES  \
# 0                            CIÊNCIAS BIOLÓGICAS III           10001018
# 1                                   INTERDISCIPLINAR           10001018
# 2                                          GEOGRAFIA           10001018
# 3  ADMINISTRAÇÃO PÚBLICA E DE EMPRESAS, CIÊNCIAS ...           10001018
# 4                                         PSICOLOGIA           10001018
#
#   CD_ENTIDADE_EMEC SG_ENTIDADE_ENSINO  ... CD_CONCEITO_PROGRAMA  \
# 0              699               UNIR  ...                    3
# 1              699               UNIR  ...                    4
# 2              699               UNIR  ...                    4
# 3              699               UNIR  ...                    4
# 4              699               UNIR  ...                    3
#
#   ANO_INICIO_PROGRAMA AN_INICIO_CURSO IN_REDE SG_ENTIDADE_ENSINO_REDE  \
# 0                2001       2001/2005     NÃO                     NaN
# 1                1999       1999/2013     NÃO                     NaN
# 2                2006       2006/2015     NÃO                     NaN
# 3                2006            2006     NÃO                     NaN
# 4                2009            2009     NÃO                     NaN
#
#   DS_SITUACAO_PROGRAMA DT_SITUACAO_PROGRAMA ID_ADD_FOTO_PROGRAMA_IES  \
# 0     EM FUNCIONAMENTO   30DEC2013:00:00:00                   121358
# 1     EM FUNCIONAMENTO   13NOV2013:00:00:00                   122262
# 2     EM FUNCIONAMENTO   19JUN2013:00:00:00                   123170
# 3     EM FUNCIONAMENTO   30DEC2013:00:00:00                   122595
# 4     EM FUNCIONAMENTO   29MAY2013:00:00:00                   121783
#
#   ID_ADD_FOTO_PROGRAMA DS_CLIENTELA_QUADRIENAL_2017
# 0                57437                    AVALIAÇÃO
# 1                58288                    AVALIAÇÃO
# 2                59126                    AVALIAÇÃO
# 3                58559                    AVALIAÇÃO
# 4                57820                    AVALIAÇÃO
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4186 entries, 0 to 4185
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   AN_BASE                        4186 non-null   int64
#  1   NM_GRANDE_AREA_CONHECIMENTO    4186 non-null   object
#  2   NM_AREA_CONHECIMENTO           4186 non-null   object
#  3   NM_SUBAREA_CONHECIMENTO        4186 non-null   object
#  4   NM_ESPECIALIDADE               4186 non-null   object
#  5   CD_AREA_AVALIACAO              4186 non-null   int64
#  6   NM_AREA_AVALIACAO              4186 non-null   object
#  7   CD_ENTIDADE_CAPES              4186 non-null   int64
#  8   CD_ENTIDADE_EMEC               4186 non-null   object
#  9   SG_ENTIDADE_ENSINO             4186 non-null   object
#  10  NM_ENTIDADE_ENSINO             4186 non-null   object
#  11  CS_STATUS_JURIDICO             4186 non-null   object
#  12  DS_DEPENDENCIA_ADMINISTRATIVA  4186 non-null   object
#  13  DS_ORGANIZACAO_ACADEMICA       4186 non-null   object
#  14  NM_REGIAO                      4186 non-null   object
#  15  NM_MUNICIPIO_PROGRAMA_IES      4186 non-null   object
#  16  NM_MODALIDADE_PROGRAMA         4186 non-null   object
#  17  CD_PROGRAMA_IES                4186 non-null   object
#  18  NM_PROGRAMA_IES                4186 non-null   object
#  19  NM_PROGRAMA_IDIOMA             4186 non-null   object
#  20  SG_UF_PROGRAMA                 4186 non-null   object
#  21  NM_GRAU_PROGRAMA               4186 non-null   object
#  22  CD_CONCEITO_PROGRAMA           4186 non-null   int64
#  23  ANO_INICIO_PROGRAMA            4186 non-null   int64
#  24  AN_INICIO_CURSO                4186 non-null   object
#  25  IN_REDE                        4186 non-null   object
#  26  SG_ENTIDADE_ENSINO_REDE        98 non-null     object
#  27  DS_SITUACAO_PROGRAMA           4186 non-null   object
#  28  DT_SITUACAO_PROGRAMA           4186 non-null   object
#  29  ID_ADD_FOTO_PROGRAMA_IES       4186 non-null   int64
#  30  ID_ADD_FOTO_PROGRAMA           4186 non-null   int64
#  31  DS_CLIENTELA_QUADRIENAL_2017   4186 non-null   object
# dtypes: int64(7), object(25)
# memory usage: 1.0+ MB

# %%
#Vendo como os estados desempenham 
estados=df.groupby('SG_UF_PROGRAMA').mean()['CD_CONCEITO_PROGRAMA']
estados=estados.apply(lambda x: round(x,2))
estados.sort_values(ascending=False)
# Out:
# SG_UF_PROGRAMA
# SP    4.40
# RJ    4.21
# RS    4.10
# DF    4.06
# MG    4.03
# SC    3.90
# PE    3.82
# CE    3.76
# PR    3.71
# PB    3.63
# BA    3.62
# RN    3.59
# PA    3.53
# GO    3.51
# ES    3.51
# AM    3.42
# SE    3.42
# MS    3.41
# AL    3.41
# MT    3.37
# AP    3.25
# RO    3.25
# MA    3.24
# TO    3.23
# PI    3.20
# AC    3.20
# RR    3.14
# Name: CD_CONCEITO_PROGRAMA, dtype: float64

# %%
#Vendo como as centro de pesquisas desempenham
unis=df[df['SG_UF_PROGRAMA']=='RJ']
unis=unis.groupby('SG_ENTIDADE_ENSINO').mean()['CD_CONCEITO_PROGRAMA']
unis=unis.apply(lambda x: round(x,2))
unis.sort_values(ascending=False)
# Out:
# SG_ENTIDADE_ENSINO
# INCA          6.00
# LNCC          6.00
# IMPA          5.50
# CBPF          5.50
# SBM           5.00
# PUC-RIO       4.88
# UFRJ          4.79
# FGV/RJ        4.67
# FIOCRUZ       4.60
# ON            4.50
# UERJ          4.33
# UNESA         4.20
# UENF          4.07
# IBMEC         4.00
# IEAPM         4.00
# ENCE          4.00
# INPI          4.00
# JBRJ          4.00
# ECEME         4.00
# IRD           4.00
# UNIGRANRIO    4.00
# UNIFA         4.00
# UFF           3.83
# UVA           3.80
# UNIVERSO      3.67
# UFRRJ         3.66
# IME           3.62
# UNIRIO        3.55
# UNIFOA        3.50
# UNISUAM       3.50
# INMETRO       3.50
# UCAM          3.43
# CEFET/RJ      3.38
# IFRJ          3.33
# UCP/RJ        3.25
# INC           3.00
# ESPM          3.00
# CESGRANRIO    3.00
# CPII          3.00
# USS           3.00
# EGN           3.00
# MAST          3.00
# UEZO          3.00
# FCRB          3.00
# INTO          3.00
# USU           3.00
# FUCAPE-RJ     3.00
# IPHAN         3.00
# IEN           3.00
# IFF           3.00
# UNIPLI        2.00
# Name: CD_CONCEITO_PROGRAMA, dtype: float64

# %%
def conceito_capes(universidade:str):
    '''Faz um gráfico de barras do conceito CAPES dos conceitos dos PPG de uma universidade.'''
    uni=df[df['SG_ENTIDADE_ENSINO']==universidade]
    sns.countplot(x='CD_CONCEITO_PROGRAMA',data=uni,color='black')
    plt.title('Coceito CAPES de PPG da '+str(universidade))
    plt.xlabel('Conceito Capes do Programa')
    plt.ylabel('Contagem')

# %%
conceito_capes('UERJ')

# %%
df[df['SG_ENTIDADE_ENSINO']=='UERJ'].query("CD_CONCEITO_PROGRAMA ==4")
# Out:
#       AN_BASE  NM_GRANDE_AREA_CONHECIMENTO  NM_AREA_CONHECIMENTO  \
# 1373     2016  LINGÜÍSTICA, LETRAS E ARTES                LETRAS
# 1375     2016   CIÊNCIAS SOCIAIS APLICADAS               DIREITO
# 1377     2016          CIÊNCIAS BIOLÓGICAS        BIOLOGIA GERAL
# 1378     2016          CIÊNCIAS BIOLÓGICAS         MICROBIOLOGIA
# 1382     2016   CIÊNCIAS EXATAS E DA TERRA           GEOCIÊNCIAS
# 1385     2016             CIÊNCIAS HUMANAS            PSICOLOGIA
# 1389     2016   CIÊNCIAS SOCIAIS APLICADAS              ECONOMIA
# 1391     2016                  ENGENHARIAS      ENGENHARIA CIVIL
# 1393     2016            CIÊNCIAS DA SAÚDE              MEDICINA
# 1395     2016                  ENGENHARIAS    ENGENHARIA QUÍMICA
# 1398     2016   CIÊNCIAS SOCIAIS APLICADAS    DESENHO INDUSTRIAL
# 1399     2016            CIÊNCIAS DA SAÚDE        SAÚDE COLETIVA
# 1401     2016                  ENGENHARIAS   ENGENHARIA MECÂNICA
# 1402     2016             MULTIDISCIPLINAR   CIÊNCIAS AMBIENTAIS
# 1403     2016             CIÊNCIAS HUMANAS              HISTÓRIA
# 1409     2016            CIÊNCIAS DA SAÚDE              NUTRIÇÃO
# 1411     2016   CIÊNCIAS EXATAS E DA TERRA          OCEANOGRAFIA
# 1412     2016          CIÊNCIAS BIOLÓGICAS              BOTÂNICA
# 1413     2016             CIÊNCIAS HUMANAS      CIÊNCIA POLÍTICA
# 1420     2016             MULTIDISCIPLINAR                ENSINO
# 1422     2016            CIÊNCIAS DA SAÚDE       EDUCAÇÃO FÍSICA
# 1423     2016                  ENGENHARIAS  ENGENHARIA SANITÁRIA
#
#                  NM_SUBAREA_CONHECIMENTO NM_ESPECIALIDADE  CD_AREA_AVALIACAO  \
# 1373               LITERATURA BRASILEIRA    NÃO SE APLICA                 41
# 1375                       NÃO SE APLICA    NÃO SE APLICA                 26
# 1377                       NÃO SE APLICA    NÃO SE APLICA                  6
# 1378                       NÃO SE APLICA    NÃO SE APLICA                  9
# 1382                       NÃO SE APLICA    NÃO SE APLICA                  5
# 1385  TRATAMENTO E PREVENÇÃO PSICOLÓGICA    NÃO SE APLICA                 37
# 1389                       NÃO SE APLICA    NÃO SE APLICA                 28
# 1391                       NÃO SE APLICA    NÃO SE APLICA                 10
# 1393                       NÃO SE APLICA    NÃO SE APLICA                 15
# 1395                       NÃO SE APLICA    NÃO SE APLICA                 12
# 1398                       NÃO SE APLICA    NÃO SE APLICA                 29
# 1399                       NÃO SE APLICA    NÃO SE APLICA                 22
# 1401                       NÃO SE APLICA    NÃO SE APLICA                 13
# 1402                       NÃO SE APLICA    NÃO SE APLICA                 49
# 1403                       NÃO SE APLICA    NÃO SE APLICA                 40
# 1409                       NÃO SE APLICA    NÃO SE APLICA                 50
# 1411              OCEANOGRAFIA GEOLÓGICA    NÃO SE APLICA                  5
# 1412                       NÃO SE APLICA    NÃO SE APLICA                  7
# 1413              POLÍTICA INTERNACIONAL    NÃO SE APLICA                 39
# 1420                       NÃO SE APLICA    NÃO SE APLICA                 46
# 1422                       NÃO SE APLICA    NÃO SE APLICA                 21
# 1423                SANEAMENTO AMBIENTAL    NÃO SE APLICA                 10
#
#                                NM_AREA_AVALIACAO  CD_ENTIDADE_CAPES  \
# 1373                        LETRAS / LINGUÍSTICA           31004016
# 1375                                     DIREITO           31004016
# 1377                       CIÊNCIAS BIOLÓGICAS I           31004016
# 1378                     CIÊNCIAS BIOLÓGICAS III           31004016
# 1382                                 GEOCIÊNCIAS           31004016
# 1385                                  PSICOLOGIA           31004016
# 1389                                    ECONOMIA           31004016
# 1391                               ENGENHARIAS I           31004016
# 1393                                  MEDICINA I           31004016
# 1395                              ENGENHARIAS II           31004016
# 1398             ARQUITETURA, URBANISMO E DESIGN           31004016
# 1399                              SAÚDE COLETIVA           31004016
# 1401                             ENGENHARIAS III           31004016
# 1402                         CIÊNCIAS AMBIENTAIS           31004016
# 1403                                    HISTÓRIA           31004016
# 1409                                    NUTRIÇÃO           31004016
# 1411                                 GEOCIÊNCIAS           31004016
# 1412                              BIODIVERSIDADE           31004016
# 1413  CIÊNCIA POLÍTICA E RELAÇÕES INTERNACIONAIS           31004016
# 1420                                      ENSINO           31004016
# 1422                             EDUCAÇÃO FÍSICA           31004016
# 1423                               ENGENHARIAS I           31004016
#
#      CD_ENTIDADE_EMEC SG_ENTIDADE_ENSINO  ... CD_CONCEITO_PROGRAMA  \
# 1373              547               UERJ  ...                    4
# 1375              547               UERJ  ...                    4
# 1377              547               UERJ  ...                    4
# 1378              547               UERJ  ...                    4
# 1382              547               UERJ  ...                    4
# 1385              547               UERJ  ...                    4
# 1389              547               UERJ  ...                    4
# 1391              547               UERJ  ...                    4
# 1393              547               UERJ  ...                    4
# 1395              547               UERJ  ...                    4
# 1398              547               UERJ  ...                    4
# 1399              547               UERJ  ...                    4
# 1401              547               UERJ  ...                    4
# 1402              547               UERJ  ...                    4
# 1403              547               UERJ  ...                    4
# 1409              547               UERJ  ...                    4
# 1411              547               UERJ  ...                    4
# 1412              547               UERJ  ...                    4
# 1413              547               UERJ  ...                    4
# 1420              547               UERJ  ...                    4
# 1422              547               UERJ  ...                    4
# 1423              547               UERJ  ...                    4
#
#      ANO_INICIO_PROGRAMA AN_INICIO_CURSO IN_REDE SG_ENTIDADE_ENSINO_REDE  \
# 1373                1988       1988/1993     NÃO                     NaN
# 1375                1991       1991/1995     NÃO                     NaN
# 1377                1993       1993/2003     NÃO                     NaN
# 1378                1994       1994/2006     NÃO                     NaN
# 1382                1995       1995/2001     NÃO                     NaN
# 1385                1998       1998/2007     NÃO                     NaN
# 1389                2003       2003/2014     NÃO                     NaN
# 1391                2003       2003/2012     NÃO                     NaN
# 1393                2002       2002/2002     NÃO                     NaN
# 1395                2004       2004/2012     NÃO                     NaN
# 1398                2005       2005/2013     NÃO                     NaN
# 1399                2000            2000     NÃO                     NaN
# 1401                2006       2006/2010     NÃO                     NaN
# 1402                2006            2006     NÃO                     NaN
# 1403                2006       2006/2015     NÃO                     NaN
# 1409                2008       2008/2010     NÃO                     NaN
# 1411                2008       2008/2015     NÃO                     NaN
# 1412                2009       2009/2011     NÃO                     NaN
# 1413                2009       2009/2015     NÃO                     NaN
# 1420                2014            2014     NÃO                     NaN
# 1422                2015       2015/2015     NÃO                     NaN
# 1423                2015            2015     NÃO                     NaN
#
#      DS_SITUACAO_PROGRAMA DT_SITUACAO_PROGRAMA ID_ADD_FOTO_PROGRAMA_IES  \
# 1373     EM FUNCIONAMENTO   07AUG2010:00:00:00                   119696
# 1375     EM FUNCIONAMENTO   01JUN2010:00:00:00                   123976
# 1377     EM FUNCIONAMENTO   01JUN2010:00:00:00                   119581
# 1378     EM FUNCIONAMENTO   20MAR2014:00:00:00                   121837
# 1382     EM FUNCIONAMENTO   09AUG2012:00:00:00                   121727
# 1385     EM FUNCIONAMENTO   10OCT2012:00:00:00                   119717
# 1389     EM FUNCIONAMENTO   13JUN2012:00:00:00                   122364
# 1391     EM FUNCIONAMENTO   16APR2013:00:00:00                   121973
# 1393     EM FUNCIONAMENTO   25APR2013:00:00:00                   121049
# 1395     EM FUNCIONAMENTO   20SEP2012:00:00:00                   122292
# 1398     EM FUNCIONAMENTO   20MAY2013:00:00:00                   119855
# 1399     EM FUNCIONAMENTO   12DEC2013:00:00:00                   122345
# 1401     EM FUNCIONAMENTO   04OCT2010:00:00:00                   123325
# 1402     EM FUNCIONAMENTO   14MAY2012:00:00:00                   119630
# 1403     EM FUNCIONAMENTO   29JUL2013:00:00:00                   122731
# 1409     EM FUNCIONAMENTO   30OCT2012:00:00:00                   122121
# 1411     EM FUNCIONAMENTO   26APR2013:00:00:00                   122366
# 1412     EM FUNCIONAMENTO   14MAR2014:00:00:00                   122821
# 1413     EM FUNCIONAMENTO   15JAN2013:00:00:00                   122242
# 1420     EM FUNCIONAMENTO   23AUG2013:00:00:00                   122182
# 1422     EM FUNCIONAMENTO   17NOV2014:00:00:00                   121347
# 1423     EM FUNCIONAMENTO   06MAY2015:00:00:00                   120594
#
#      ID_ADD_FOTO_PROGRAMA DS_CLIENTELA_QUADRIENAL_2017
# 1373                55945                    AVALIAÇÃO
# 1375                59856                    AVALIAÇÃO
# 1377                55867                    AVALIAÇÃO
# 1378                57870                    AVALIAÇÃO
# 1382                57785                    AVALIAÇÃO
# 1385                55927                    AVALIAÇÃO
# 1389                58368                    AVALIAÇÃO
# 1391                58024                    AVALIAÇÃO
# 1393                57131                    AVALIAÇÃO
# 1395                58304                    AVALIAÇÃO
# 1398                56081                    AVALIAÇÃO
# 1399                58356                    AVALIAÇÃO
# 1401                59270                    AVALIAÇÃO
# 1402                55899                    AVALIAÇÃO
# 1403                58728                    AVALIAÇÃO
# 1409                58165                    AVALIAÇÃO
# 1411                58370                    AVALIAÇÃO
# 1412                58815                    AVALIAÇÃO
# 1413                58250                    AVALIAÇÃO
# 1420                58210                    AVALIAÇÃO
# 1422                57415               ACOMPANHAMENTO
# 1423                56725               ACOMPANHAMENTO
#
# [22 rows x 32 columns]

# %%
#ano de fundação versus conceito

ano=df.groupby('ANO_INICIO_PROGRAMA').mean()['CD_CONCEITO_PROGRAMA']
ano=ano.apply(lambda x: round(x,2))
ano.sort_values(ascending=False)
plt.scatter(ano.index,ano.values,color='black',marker='.')
plt.xlabel('Ano')
plt.ylabel('Conceito CAPES')
plt.title('Ano de fundação x CONCEITO CAPES')
# Out:
# Text(0.5, 1.0, 'Ano de fundação x CONCEITO CAPES')

# %%
from Reglin import *

# %%
reglin2(ano.index,ano.values)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.813
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     243.3
# Date:                Fri, 20 Nov 2020   Prob (F-statistic):           4.89e-22
# Time:                        16:17:10   Log-Likelihood:                -26.442
# No. Observations:                  58   AIC:                             56.88
# Df Residuals:                      56   BIC:                             61.01
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         92.9730      5.657     16.435      0.000      81.640     104.306
# x1            -0.0444      0.003    -15.597      0.000      -0.050      -0.039
# ==============================================================================
# Omnibus:                        5.394   Durbin-Watson:                   0.707
# Prob(Omnibus):                  0.067   Jarque-Bera (JB):                4.949
# Skew:                          -0.436   Prob(JB):                       0.0842
# Kurtosis:                       4.135   Cond. No.                     2.20e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
