# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sklearn as skt

# %%
df1 = pd.read_csv('/content/drive/My Drive/bases_capesppg_docentes/capesppg_docentes_2013.csv',sep=';',encoding='latin1')
df2 = pd.read_csv('/content/drive/My Drive/bases_capesppg_docentes/capesppg_docentes_2014.csv',sep=';',encoding='latin1')
df3 = pd.read_csv('/content/drive/My Drive/bases_capesppg_docentes/capesppg_docentes_2015.csv',sep=';',encoding='latin1')
df4 = pd.read_csv('/content/drive/My Drive/bases_capesppg_docentes/capesppg_docentes_2016.csv',sep=';',encoding='latin1')
df5 = pd.read_csv('/content/drive/My Drive/bases_capesppg_docentes/capesppg_docentes_2017.csv',sep=';',encoding='latin1')
df6 = pd.read_csv('/content/drive/My Drive/bases_capesppg_docentes/capesppg_docentes_2018.csv',sep=';',encoding='latin1')
df7 = pd.read_csv('/content/drive/My Drive/bases_capesppg_docentes/capesppg_docentes_2019.csv',sep=';',encoding='latin1')

frames = [df1, df2, df3, df4, df5, df6, df7]
df = pd.concat(frames)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    AN_BASE  ...  DS_CLIENTELA_QUADRIENAL_2017
# 0     2013  ...                     AVALIAÇÃO
# 1     2013  ...                     AVALIAÇÃO
# 2     2013  ...                     AVALIAÇÃO
# 3     2013  ...                     AVALIAÇÃO
# 4     2013  ...                     AVALIAÇÃO
#
# [5 rows x 43 columns]

# %%
database.describe()
# Out:
#              AN_BASE  ...  ID_ADD_FOTO_PROGRAMA_IES
# count  165272.000000  ...             165272.000000
# mean     2013.518237  ...             104890.285481
# std         0.499669  ...              16125.115159
# min      2013.000000  ...              20932.000000
# 25%      2013.000000  ...              97083.000000
# 50%      2014.000000  ...             112086.000000
# 75%      2014.000000  ...             115630.000000
# max      2014.000000  ...             119806.000000
#
# [8 rows x 10 columns]

# %%
sns.countplot(x='AN_BASE', data = df)

# %%
sns.countplot(x='AN_BASE', data = df, hue='CD_CONCEITO_PROGRAMA', palette='rainbow')

# %%
df.head()
# Out:
#    AN_BASE  ...  DS_CLIENTELA_QUADRIENAL_2017
# 0     2013  ...                     AVALIAÇÃO
# 1     2013  ...                     AVALIAÇÃO
# 2     2013  ...                     AVALIAÇÃO
# 3     2013  ...                     AVALIAÇÃO
# 4     2013  ...                     AVALIAÇÃO
#
# [5 rows x 43 columns]

# %%
df = df.drop(columns=['CD_ENTIDADE_CAPES', 'CD_ENTIDADE_EMEC','DS_DEPENDENCIA_ADMINISTRATIVA','NM_MUNICIPIO_PROGRAMA_IES', 'TP_DOCUMENTO_DOCENTE', 'NR_DOCUMENTO_DOCENTE', 'NM_DOCENTE', 'DS_TIPO_NACIONALIDADE_DOCENTE','DS_CATEGORIA_DOCENTE','CD_AREA_BASICA_TITULACAO', 'NM_AREA_BASICA_TITULACAO','ID_ADD_FOTO_PROGRAMA', 'ID_ADD_FOTO_PROGRAMA_IES' ])
df.head()
# Out:
#    AN_BASE  ...  DS_CLIENTELA_QUADRIENAL_2017
# 0     2013  ...                     AVALIAÇÃO
# 1     2013  ...                     AVALIAÇÃO
# 2     2013  ...                     AVALIAÇÃO
# 3     2013  ...                     AVALIAÇÃO
# 4     2013  ...                     AVALIAÇÃO
#
# [5 rows x 30 columns]

# %%
df.to_csv(r'/content/drive/My Drive/bases_capesppg_docentes/capesppg_docentes_2013-2019.csv', index=False)
